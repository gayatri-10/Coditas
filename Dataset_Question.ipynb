# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\gayat\Data_Science\data\Customer.csv")
df.head()
# Out:
# C:\Users\gayat\AppData\Local\Temp\ipykernel_11148\2771049525.py:1: DtypeWarning: Columns (1,5,6,7,14,22,25,27,28,29,30,31,32,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\gayat\Data_Science\data\Customer.csv")
#    Unnamed: 0 Customer_ID  Job_ID   Sort_Name  Bill_To_Customer Zip_Code  \
# 0           0      104546       0  JODYDEWITT               NaN    97301
# 1           1      104831       0  LOWELLSLEI               NaN    97301
# 2           2      104852       0  FORDINGPAT               NaN    97301
# 3           3      105503       0  TORRESANGE               NaN    97301
# 4           4      106325       0  GARCIASFEN               NaN    97301
#
#   Area_Code Phone_Number  Loyalty_ID Account_Type  ... Account_Code_1  \
# 0       503      2692791         NaN            G  ...              P
# 1       503      4091868         NaN            G  ...              P
# ...

# %%
df1 = df.copy()

# %%
df1.drop(['Loyalty_ID'], axis = 1, inplace = True)

# %%
df1.head()
# Out:
#    Unnamed: 0 Customer_ID  Job_ID   Sort_Name  Bill_To_Customer Zip_Code  \
# 0           0      104546       0  JODYDEWITT               NaN    97301
# 1           1      104831       0  LOWELLSLEI               NaN    97301
# 2           2      104852       0  FORDINGPAT               NaN    97301
# 3           3      105503       0  TORRESANGE               NaN    97301
# 4           4      106325       0  GARCIASFEN               NaN    97301
#
#   Area_Code Phone_Number Account_Type Charge_Allowed  ... Account_Code_1  \
# 0       503      2692791            G              N  ...              P
# 1       503      4091868            G              N  ...              P
# 2       503      3152126            G              N  ...              P
# 3       503      4096875            G              N  ...              P
# 4       503      7982695            G              N  ...              P
#
#   Account_Code_2 Account_Code_3 Account_Code_4 Standard_Selling_Price  \
# ...

# %%
# Dsiplaying only the Customer_ID having Area_Code 503:

df1[df1['Area_Code'] == 503][['Customer_ID']]
# Out:
#        Customer_ID
# 0           104546
# 1           104831
# 2           104852
# 3           105503
# 4           106325
# ...            ...
# 418631      910663
# 418632      911039
# 418633      913229
# 418634      927939
# 418635      929897
#
# [127108 rows x 1 columns]
